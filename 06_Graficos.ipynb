# %%
using CSV, DataFrames, Dates, Plots, DiffEqFlux, DifferentialEquations.OrdinaryDiffEq, LaTeXStrings

# %%
df = DataFrame(CSV.File("DadosMedia.csv"))

datasTudo = df[:,"DatasMedia"]
infTudo = df[:,"InfectadosMedia"]
recTudo = df[:,"RecuperadosMedia"]
decTudo = df[:,"ObitosMedia"]

limiteE = findall(data->data==Date(2020,03,18),datasTudo)[1]
limiteD = findall(data->data==Date(2020,06,30),datasTudo)[1]

datasOnda = datasTudo[limiteE:limiteD]
infOnda = infTudo[limiteE:limiteD]
recOnda = recTudo[limiteE:limiteD]
decOnda = decTudo[limiteE:limiteD]

dadosOnda = hcat(infOnda,recOnda,decOnda)

nothing

# %%
expIniciais = 2000.
astIniciais = 1000.
reaIniciais = 100.

u₀_SIRD  = [infOnda[1], recOnda[1], decOnda[1]]

nothing

# %%
N = 55

S₀_SIRD_1 = DataFrame(CSV.File(string("Parametros_SIRD_UODE_b/c_initSIRD_", N, "Dias.csv")))[1, 1]
θ₁_SIRD_1 = DataFrame(CSV.File(string("Parametros_SIRD_UODE_b/paramsSIRD_", N, "Dias.csv")))[:, 1]
θ₁_UODE_1 = DataFrame(CSV.File(string("Parametros_SIRD_UODE_b/paramsSIRD_UODE_b_", N, "Dias.csv")))[:, 1]

NN4x1 = FastChain(FastDense(4,16,tanh), FastDense(16,16,tanh), FastDense(16,1), (x, θ) -> x.^2)

S₀_SIRD_2 = DataFrame(CSV.File(string("Parametros_SIRD_UODE_bSI/c_initSIRD_", N, "Dias.csv")))[1, 1]
θ₁_SIRD_2 = DataFrame(CSV.File(string("Parametros_SIRD_UODE_bSI/paramsSIRD_", N, "Dias.csv")))[:, 1]
θ₁_UODE_2 = DataFrame(CSV.File(string("Parametros_SIRD_UODE_bSI/paramsSIRD_UODE_bSI_", N, "Dias.csv")))[:, 1]

NN2x1 = FastChain(FastDense(2,16,tanh), FastDense(16,16,tanh), FastDense(16,1), (x, θ) -> x.^2)

nothing

# %%
function dudtSIR!(du, u, θ, t)
    S, I, R, D = u
    N = S + I + R
    β, γ_R, γ_D = θ

    E_novos = β^2 * I*S / N
    dS = -E_novos 
    dI = E_novos - (γ_R^2 + γ_D^2)*I
    dR = γ_R^2*I
    dD = γ_D^2*I

    du[1] = dS; du[2] = dI; du[3] = dR; du[4] = dD
end

function dudtUODE_1!(du, u, θ, t)
    S, I, R, D = u
    N = S + I + R
    γ_R, γ_D = θ[1:2]

    E_novos =  NN4x1(u, θ[3:end])[1] * I*S / N
    dS = -E_novos 
    dI = E_novos - (γ_R^2 + γ_D^2)*I
    dR = γ_R^2*I
    dD = γ_D^2*I

    du[1] = dS; du[2] = dI; du[3] = dR; du[4] = dD
end

function dudtUODE_2!(du, u, θ, t)
    S, I, R, D = u
    N = S + I + R
    γ_R, γ_D = θ[1:2]

    E_novos =  NN2x1([S/N, I], θ[3:end])[1]
    dS = -E_novos 
    dI = E_novos - (γ_R^2 + γ_D^2)*I
    dR = γ_R^2*I
    dD = γ_D^2*I

    du[1] = dS; du[2] = dI; du[3] = dR; du[4] = dD
end

nothing

# %%
dadosTreino = dadosOnda[1:N, :]    
fatorReducao = maximum(dadosTreino)

h = 0.02

modeloSIR = solve(ODEProblem(dudtSIR!, [S₀_SIRD_1 * fatorReducao; u₀_SIRD], (1., size(dadosOnda)[1]), θ₁_SIRD_1),
    saveat = h)

infSIR = modeloSIR[2, :]
recSIR = modeloSIR[3, :]
decSIR = modeloSIR[4, :]

modeloUODE_1 = solve(ODEProblem(dudtUODE_1!, [S₀_SIRD_1; u₀_SIRD ./ fatorReducao], (1., size(dadosOnda)[1]), θ₁_UODE_1),
    saveat = h) .* fatorReducao

infUODE_1 = modeloUODE_1[2, :]
recUODE_1 = modeloUODE_1[3, :]
decUODE_1 = modeloUODE_1[4, :]

modeloUODE_2 = solve(ODEProblem(dudtUODE_2!, [S₀_SIRD_2; u₀_SIRD ./ fatorReducao], (1., size(dadosOnda)[1]), θ₁_UODE_2),
    saveat = h) .* fatorReducao

infUODE_2 = modeloUODE_2[2, :]
recUODE_2 = modeloUODE_2[3, :]
decUODE_2 = modeloUODE_2[4, :]

nothing

# %%
pl1 = plot(infOnda, lw = 3, color = 1, linestyle = :dot, label = "")
plot!(pl1, recOnda, lw = 3, color = 2, linestyle = :dot, label = "")
plot!(pl1, decOnda, lw = 3, color = 3, linestyle = :dot, label = "")

plot!(pl1, 1.:h:105., infSIR, lw = 3, color = 1, label = "Infectados")
plot!(pl1, 1.:h:105., recSIR, lw = 3, color = 2, label = "Recuperados")
plot!(pl1, 1.:h:105., decSIR, lw = 3, color = 3, label = "Decessos")

plot!(pl1, [N], seriestype = "vline", label = "", color = "red")

plot!(pl1, title = L"\mathrm{SIRD} \hspace{0.5} [N = 55]", framestyle = :box, xlim = (1, 105), ylim = (-1_000, 48_500),
    legend = false)

# %%
pl2 = plot(infOnda, lw = 3, color = 1, linestyle = :dot, label = "Infectados (dados)")
plot!(pl2, recOnda, lw = 3, color = 2, linestyle = :dot, label = "Recuperados (dados)")
plot!(pl2, decOnda, lw = 3, color = 3, linestyle = :dot, label = "Decessos (dados)")

plot!(pl2, 1.:h:105., infUODE_1, lw = 3, color = 1)
plot!(pl2, 1.:h:105., recUODE_1, lw = 3, color = 2)
plot!(pl2, 1.:h:105., decUODE_1, lw = 3, color = 3)

plot!(pl2, [N], seriestype = "vline", label = "Último dia do ajuste", color = "red")

plot!(pl2, title = L"\mathrm{SIRD\,\,\,UODE}\,\,\,\beta \hspace{0.5} [N = 55]", legend = false, framestyle = :box, xlim =
    (1, 105), ylim = (-1_000, 48_500))

# %%
pl3 = plot(infOnda, lw = 3, color = 1, linestyle = :dot, label = "Infectados (dados)")
plot!(pl3, recOnda, lw = 3, color = 2, linestyle = :dot, label = "Recuperados (dados)")
plot!(pl3, decOnda, lw = 3, color = 3, linestyle = :dot, label = "Decessos (dados)")

plot!(pl3, 1.:h:105., infUODE_2, lw = 3, color = 1)
plot!(pl3, 1.:h:105., recUODE_2, lw = 3, color = 2)
plot!(pl3, 1.:h:105., decUODE_2, lw = 3, color = 3)

plot!(pl3, [N], seriestype = "vline", label = "Último dia do ajuste", color = "red")

plot!(pl3, title = L"\mathrm{SIRD\,\,\,UODE}\,\,\,\beta\,SI \hspace{0.5} [N = 55]", legend = false, framestyle =
    :box, xlim = (1, 105), ylim = (-1_000, 48_500))

# %%
fig1 = plot(pl1, pl2, pl3, layout = (1, 3), ticks = false, fontfamily = "Computer Modern", titlefontsize = 12)

using Plots.PlotMeasures

plot!(fig1, size = (900, 300))

display(fig1)
savefig(fig1, string("full_model_", N, "_days.pdf"))

# %%
pl4 = plot(infOnda, lw = 3, color = "gray25", label = "Dados", linestyle = :dot)

plot!(pl4, lw = 3, color = "#f5a201", 1.:h:105., infSIR, label = "SIRD")
plot!(pl4, lw = 3, color = "#8ECAE6", 1.:h:105., infUODE_1, label = "SIRD UODE β")
plot!(pl4, lw = 3, color = "#126782", 1.:h:105., infUODE_2, label = "SIRD UODE βSI")

plot!(pl4, [N], seriestype = "vline", label = "", color = "red")

plot!(pl4, title = L"\mathrm{Infectados} \hspace{0.5} [N = 55]", legend = false, framestyle = :box, xlim = (1, 105),
    ylim = (225, 18_500))

# %%
pl5 = plot(recOnda, lw = 3, color = "gray25", label = "Dados", linestyle = :dot)

plot!(pl5, lw = 3, color = "#f5a201", 1.:h:105., recSIR, label = "SIRD")
plot!(pl5, lw = 3, color = "#8ECAE6", 1.:h:105., recUODE_1, label = "SIRD UODE b")
plot!(pl5, lw = 3, color = "#126782", 1.:h:105., recUODE_2, label = "SIRD UODE bSI")

plot!(pl5, [N], seriestype = "vline", label = "", color = "red")

plot!(pl5, title = L"\mathrm{Recuperados} \hspace{0.5} [N = 55]", legend = false, framestyle = :box, xlim = (1, 105),
    ylim = (-1_000, 48_500))

# %%
pl6 = plot(decOnda, lw = 3, color = "gray25", label = "Dados", linestyle = :dot)

plot!(pl6, lw = 3, color = "#f5a201", 1.:h:105., decSIR, label = "SIRD")
plot!(pl6, lw = 3, color = "#8ECAE6", 1.:h:105., decUODE_1, label = "SIRD UODE b")
plot!(pl6, lw = 3, color = "#126782", 1.:h:105., decUODE_2, label = "SIRD UODE bSI")

plot!(pl6, [N], seriestype = "vline", label = "", color = "red")

plot!(pl6, title = L"\mathrm{Decessos} \hspace{0.5} [N = 55]", legend = false, framestyle = :box, xlim = (1, 105), ylim = (-150, 6400))

# %%
fig2 = plot(pl4, pl5, pl6, layout = (1, 3), ticks = false, fontfamily = "Computer Modern", titlefontsize = 12)

using Plots.PlotMeasures

plot!(fig2, size = (900, 300))

display(fig2)
savefig(fig2, string("model_vars_", N, "_days.pdf"))
